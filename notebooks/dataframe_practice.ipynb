# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from io import StringIO
import os
from data_processing import clean_gamelog

# %%
full_name = 'Lebron_James'

# %%
file_path = f"data/dataframes/{full_name}_2025_dataframe.html"
stats_df = pd.read_html(file_path)[0]

# %%
stats_df.tail(20)
# Out:
#           Date Location Opponent        FG       FGA       FG%        3P  \
# 62  2025-03-10     Away      BRK  Inactive  Inactive  Inactive  Inactive
# 63  2025-03-13     Away      MIL  Inactive  Inactive  Inactive  Inactive
# 64  2025-03-14     Away      DEN  Inactive  Inactive  Inactive  Inactive
# 65  2025-03-16     Home      PHO  Inactive  Inactive  Inactive  Inactive
# 66  2025-03-17     Home      SAS  Inactive  Inactive  Inactive  Inactive
# 67  2025-03-19     Home      DEN  Inactive  Inactive  Inactive  Inactive
# 68  2025-03-20     Home      MIL  Inactive  Inactive  Inactive  Inactive
# 69  2025-03-22     Home      CHI         7        16      .438         1
# 70  2025-03-24     Away      ORL         9        18      .500         0
# 71  2025-03-26     Away      IND         4        12      .333         0
# 72  2025-03-27     Away      CHI         8        20      .400         0
# 73  2025-03-29     Away      MEM        10        21      .476         2
# 74  2025-03-31     Home      HOU         5        12      .417         2
# 75  2025-04-03     Home      GSW        10        15      .667         5
# 76  2025-04-04     Home      NOP         9        17      .529         2
# 77  2025-04-06     Away      OKC         9        16      .563         1
# 78  2025-04-08     Away      OKC         8        19      .421         3
# 79  2025-04-09     Away      DAL        11        20      .550         0
# 80  2025-04-11     Home      HOU         6        11      .545         1
# 81  2025-04-13     Away      POR  Inactive  Inactive  Inactive  Inactive
#
#          3PA       3P%        2P  ...       FTA       FT%       ORB       DRB  \
# 62  Inactive  Inactive  Inactive  ...  Inactive  Inactive  Inactive  Inactive
# 63  Inactive  Inactive  Inactive  ...  Inactive  Inactive  Inactive  Inactive
# 64  Inactive  Inactive  Inactive  ...  Inactive  Inactive  Inactive  Inactive
# 65  Inactive  Inactive  Inactive  ...  Inactive  Inactive  Inactive  Inactive
# 66  Inactive  Inactive  Inactive  ...  Inactive  Inactive  Inactive  Inactive
# 67  Inactive  Inactive  Inactive  ...  Inactive  Inactive  Inactive  Inactive
# 68  Inactive  Inactive  Inactive  ...  Inactive  Inactive  Inactive  Inactive
# 69         2      .500         6  ...         5      .400         0         6
# 70         3      .000         9  ...         7      .857         3         3
# 71         3      .000         4  ...         5     1.000         3        10
# 72         5      .000         8  ...         2      .500         1         4
# 73         5      .400         8  ...         4      .750         1         5
# 74         4      .500         3  ...         4     1.000         0         8
# 75         8      .625         5  ...         9      .889         1         4
# 76         7      .286         7  ...         8      .875         0         0
# 77         1     1.000         8  ...         0       NaN         2         1
# 78         6      .500         5  ...        10      .900         0         7
# 79         4      .000        11  ...         6      .833         2         5
# 80         4      .250         5  ...         1     1.000         0         4
# 81  Inactive  Inactive  Inactive  ...  Inactive  Inactive  Inactive  Inactive
#
#          TRB       AST       STL       BLK       TOV       PTS
# 62  Inactive  Inactive  Inactive  Inactive  Inactive  Inactive
# 63  Inactive  Inactive  Inactive  Inactive  Inactive  Inactive
# 64  Inactive  Inactive  Inactive  Inactive  Inactive  Inactive
# 65  Inactive  Inactive  Inactive  Inactive  Inactive  Inactive
# 66  Inactive  Inactive  Inactive  Inactive  Inactive  Inactive
# 67  Inactive  Inactive  Inactive  Inactive  Inactive  Inactive
# 68  Inactive  Inactive  Inactive  Inactive  Inactive  Inactive
# 69         6         4         3         0         5        17
# 70         6         7         0         0         2        24
# 71        13         7         1         0         1        13
# 72         5        12         2         0         4        17
# 73         6         8         3         1         3        25
# 74         8         4         2         2         3        16
# 75         5         9         1         1         4        33
# 76         0         8         2         0         1        27
# 77         3         7         1         0         2        19
# 78         7         3         1         0         6        28
# 79         7         3         1         0         2        27
# 80         4         8         1         0         1        14
# 81  Inactive  Inactive  Inactive  Inactive  Inactive  Inactive
#
# [20 rows x 24 columns]
